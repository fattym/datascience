# %%
import pandas
from sklearn.cluster import KMeans

wateTreatment = pandas.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/water-treatment/water-treatment.data")
wateTreatment.columns=['id','Q-E','ZN-E','PH-E', 'DBO-E','DQO-E','SS-E', 'SSV-E', 'SED-E', 'COND-E', 'PH-P', 'DBO-P', 'SS-P' ,'SSV-P','SED-P',  'COND-P','PH-D','DBO-D','DQO-D', 'SS-D',  'SSV-D', 'SED-D', 'COND-D','PH-S','DBO-S','DQO-S','SS-S',  'SSV-S' ,'SED-S','COND-S','RD-DBO-P','RD-SS-P', 'RD-SED-P','RD-DBO-S','RD-DQO-S','RD-DBO-G', 'RD-DQO-G','RD-SS-G','RD-SED-G', ]         
wateTreatment.to_csv('data.csv',index=None,header=True)
wateTreatment
# Out:
#             id    Q-E  ZN-E  PH-E DBO-E DQO-E SS-E SSV-E SED-E  COND-E  ...  \
# 0     D-2/3/90  39024  3.00   7.7     ?   443  214  69.2   6.5    2660  ...
# 1     D-4/3/90  32229  5.00   7.6     ?   528  186  69.9   3.4    1666  ...
# 2     D-5/3/90  35023  3.50   7.9   205   588  192  65.6   4.5    2430  ...
# 3     D-6/3/90  36924  1.50   8.0   242   496  176  64.8   4.0    2110  ...
# 4     D-7/3/90  38572  3.00   7.8   202   372  186  68.8   4.5    1644  ...
# ..         ...    ...   ...   ...   ...   ...  ...   ...   ...     ...  ...
# 521  D-26/8/91  32723  0.16   7.7    93   252  176  56.8   2.3     894  ...
# 522  D-27/8/91  33535  0.32   7.8   192   346  172  68.6   4.0     988  ...
# 523  D-28/8/91  32922  0.30   7.4   139   367  180  64.4   3.0    1060  ...
# 524  D-29/8/91  32190  0.30   7.3   200   545  258  65.1   4.0    1260  ...
# 525  D-30/8/91  30488  0.21   7.5   152   300  132  69.7     ?    1073  ...
#
# ...

# %%
wateTreatment_= pandas.read_csv('data.csv')
# wateTreatment_.isnull().sum()
# wateTreatment_.info()
# PH-E PH-P  PH-D COND-D  floats
wateTreatment_=wateTreatment_[['id','Q-E','ZN-E', 'DBO-E','DQO-E','SS-E', 'SSV-E', 'SED-E', 'COND-E', 'DBO-P', 'SS-P' ,'SSV-P','SED-P', 'COND-P','DBO-D','DQO-D', 'SS-D',  'SSV-D', 'SED-D', 'PH-S','DBO-S','DQO-S','SS-S',  'SSV-S' ,'SED-S','COND-S','RD-DBO-P','RD-SS-P', 'RD-SED-P','RD-DBO-S','RD-DQO-S','RD-DBO-G', 'RD-DQO-G','RD-SS-G','RD-SED-G','PH-E','PH-P', 'PH-D','COND-D',]]
 
wateTreatment_
# Out:
#             id    Q-E  ZN-E DBO-E DQO-E SS-E SSV-E SED-E  COND-E DBO-P  ...  \
# 0     D-2/3/90  39024  3.00     ?   443  214  69.2   6.5    2660     ?  ...
# 1     D-4/3/90  32229  5.00     ?   528  186  69.9   3.4    1666     ?  ...
# 2     D-5/3/90  35023  3.50   205   588  192  65.6   4.5    2430   236  ...
# 3     D-6/3/90  36924  1.50   242   496  176  64.8   4.0    2110     ?  ...
# 4     D-7/3/90  38572  3.00   202   372  186  68.8   4.5    1644     ?  ...
# ..         ...    ...   ...   ...   ...  ...   ...   ...     ...   ...  ...
# 521  D-26/8/91  32723  0.16    93   252  176  56.8   2.3     894   108  ...
# 522  D-27/8/91  33535  0.32   192   346  172  68.6   4.0     988   210  ...
# 523  D-28/8/91  32922  0.30   139   367  180  64.4   3.0    1060   163  ...
# 524  D-29/8/91  32190  0.30   200   545  258  65.1   4.0    1260   191  ...
# 525  D-30/8/91  30488  0.21   152   300  132  69.7     ?    1073   150  ...
#
# ...

# %%
array=wateTreatment_.values
x=array[:,35:39]
from sklearn.cluster import KMeans
model=KMeans(n_clusters=5,random_state=42)# clasters into 5 people
model.fit(x)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
means= model.cluster_centers_
cluster = pandas.DataFrame(means,columns=['PH-E','PH-P', 'PH-D','COND-D',])
cluster
# Out:
#        PH-E      PH-P      PH-D       COND-D
# 0  7.877698  7.905036  7.880576  1710.050360
# 1  7.697600  7.728800  7.727200  1036.504000
# 2  7.878431  7.876471  7.852941  2158.588235
# 3  7.806500  7.825000  7.804500  1379.110000
# 4  7.981818  7.900000  7.845455  2759.090909

# %%
wateTreatment_['label']=  model.labels_
wateTreatment_ =wateTreatment_[wateTreatment_['label']==3]
wateTreatment_
# Out:
#              id    Q-E  ZN-E DBO-E DQO-E SS-E SSV-E SED-E  COND-E DBO-P  ...  \
# 7     D-11/3/90  29156  2.50   206   451  194  69.1   4.5    1249   206  ...
# 10    D-14/3/90  42857  1.50   238   319  292  33.8   3.5    1261   170  ...
# 13    D-18/3/90  40923  3.50   146   329  188  57.4   2.5    1300   162  ...
# 14    D-19/3/90  43830   1.5   177   512  214  58.9   5.5    1605   164  ...
# 15    D-20/3/90  39165  1.20   250   447  252  61.1   7.0    1533   275  ...
# ..          ...    ...   ...   ...   ...  ...   ...   ...     ...   ...  ...
# 496  D-25/10/91  35400  0.70   156   364  194  63.9   5.5    1680   169  ...
# 497  D-26/10/91  30964  3.30   220   540  184  62.0   3.5    1445     ?  ...
# 499  D-29/10/91  29801  1.60   172   400  136  70.1   1.5    1402   182  ...
# 502    D-2/8/91  28492  2.60   124   281  172  66.3   3.0    1520   117  ...
# 524   D-29/8/91  32190  0.30   200   545  258  65.1   4.0    1260   191  ...
#
# ...
